# %%
import pandas as pd

pd.options.display.float_format = '{:.2f}'.format
pd.set_option('display.max_columns', 100)

# %%
df_cand = pd.read_csv('datasets/consulta_cand_2018_BRASIL.csv', sep=';', encoding = 'ISO-8859-1')
df_cand.head(3)
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  21/09/2018   08:00:57         2018                2  ELEIÇÃO ORDINÁRIA
# 1  21/09/2018   08:00:57         2018                2  ELEIÇÃO ORDINÁRIA
# 2  21/09/2018   08:00:57         2018                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  \
# 0         1         297  Eleições Gerais Estaduais 2018  07/10/2018
# 1         1         297  Eleições Gerais Estaduais 2018  07/10/2018
# 2         1         297  Eleições Gerais Estaduais 2018  07/10/2018
#
#   TP_ABRANGENCIA SG_UF SG_UE           NM_UE  CD_CARGO           DS_CARGO  \
# 0       ESTADUAL    TO    TO       TOCANTINS         7  DEPUTADO ESTADUAL
# 1       ESTADUAL    RJ    RJ  RIO DE JANEIRO         7  DEPUTADO ESTADUAL
# 2       ESTADUAL    RJ    RJ  RIO DE JANEIRO         6   DEPUTADO FEDERAL
#
#    SQ_CANDIDATO  NR_CANDIDATO                    NM_CANDIDATO  \
# 0  270000610942         45123       GUTIERRES BORGES TORQUATO
# 1  190000603321         14500  ANTONIO RIBEIRO DE BRITO FILHO
# 2  190000603416          4569             JORGE AQUILES COSTA
#
#     NM_URNA_CANDIDATO NM_SOCIAL_CANDIDATO  NR_CPF_CANDIDATO  \
# 0  GUTIERRES TORQUATO              #NULO#         655089128
# 1          TONY BRITO              #NULO#        7738384735
# 2       JORGE AQUILES              #NULO#         999560719
#
#                          NM_EMAIL  CD_SITUACAO_CANDIDATURA  \
# 0        GUTIERRES45123@GMAIL.COM                       12
# 1           TONYBRITO93@GMAIL.COM                       12
# 2  JORGE.AQUILES2017@YAHOO.COM.BR                       12
#
#   DS_SITUACAO_CANDIDATURA  CD_DETALHE_SITUACAO_CAND DS_DETALHE_SITUACAO_CAND  \
# 0                    APTO                         2                 DEFERIDO
# 1                    APTO                         2                 DEFERIDO
# 2                    APTO                         2                 DEFERIDO
#
#   TP_AGREMIACAO  NR_PARTIDO SG_PARTIDO  \
# 0     COLIGAÇÃO          45       PSDB
# 1     COLIGAÇÃO          14        PTB
# 2     COLIGAÇÃO          45       PSDB
#
#                                 NM_PARTIDO  SQ_COLIGACAO  \
# 0  PARTIDO DA SOCIAL DEMOCRACIA BRASILEIRA  270000050293
# 1           PARTIDO TRABALHISTA BRASILEIRO  190000050092
# 2  PARTIDO DA SOCIAL DEMOCRACIA BRASILEIRA  190000050094
#
#            NM_COLIGACAO             DS_COMPOSICAO_COLIGACAO  CD_NACIONALIDADE  \
# 0      RENOVA TOCANTINS  PSB / PSDB / PR / PODE / MDB / PSC                 1
# 1  TRABALHAR PARA MUDAR                 SOLIDARIEDADE / PTB                 1
# 2       O RIO TEM JEITO          SOLIDARIEDADE / PSDB / PPS                 1
#
#   DS_NACIONALIDADE SG_UF_NASCIMENTO  CD_MUNICIPIO_NASCIMENTO  \
# 0  BRASILEIRA NATA               GO                       -3
# 1  BRASILEIRA NATA               RJ                       -3
# 2  BRASILEIRA NATA               RJ                       -3
#
#   NM_MUNICIPIO_NASCIMENTO DT_NASCIMENTO  NR_IDADE_DATA_POSSE  \
# 0                  URUAÇU    05/04/1984                   34
# 1          RIO DE JANEIRO    15/07/1977                   41
# 2          RIO DE JANEIRO    03/10/1971                   47
#
#    NR_TITULO_ELEITORAL_CANDIDATO  CD_GENERO  DS_GENERO  CD_GRAU_INSTRUCAO  \
# 0                    36280122771          2  MASCULINO                  8
# 1                    94831580302          2  MASCULINO                  8
# 2                    83146660302          2  MASCULINO                  8
#
#    DS_GRAU_INSTRUCAO  CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_COR_RACA  \
# 0  SUPERIOR COMPLETO                3       CASADO(A)            3
# 1  SUPERIOR COMPLETO                1     SOLTEIRO(A)            1
# 2  SUPERIOR COMPLETO                3       CASADO(A)            3
#
#   DS_COR_RACA  CD_OCUPACAO                             DS_OCUPACAO  \
# 0       PARDA          114  FISIOTERAPEUTA E TERAPEUTA OCUPACIONAL
# 1      BRANCA          999                                  OUTROS
# 2       PARDA          171                    JORNALISTA E REDATOR
#
#    NR_DESPESA_MAX_CAMPANHA  CD_SIT_TOT_TURNO DS_SIT_TOT_TURNO ST_REELEICAO  \
# 0                       -1                -1           #NULO#            N
# 1                        0                -1           #NULO#            N
# 2                        0                -1           #NULO#            N
#
#   ST_DECLARAR_BENS  NR_PROTOCOLO_CANDIDATURA          NR_PROCESSO
# 0                S                        -1  6004977620186270000
# 1                N                        -1  6010054420186190000
# 2                N                        -1  6011215020186190000

# %%
df_cand['DT_GERACAO'] = pd.to_datetime(df_cand['DT_GERACAO']).dt.strftime('%Y-%m-%d')
df_cand['DT_ELEICAO'] = pd.to_datetime(df_cand['DT_ELEICAO']).dt.strftime('%Y-%m-%d')

# %%
# Tratando erros pois há candidado com data de nascimento no ano de 1193
df_cand['DT_NASCIMENTO'] = pd.to_datetime(df_cand['DT_NASCIMENTO'], errors='coerce').dt.strftime('%Y-%m-%d')

# %%
print(df_cand.shape)
print(df_cand['SQ_CANDIDATO'].nunique())
# Out:
# (29098, 58)
# 29098

# %%
df_bens = pd.read_csv('datasets/bem_candidato_2018_BRASIL.csv', sep=';', encoding = 'ISO-8859-1', decimal=',')
df_bens.head(3)
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  21/09/2018   08:00:42         2018                2  Eleição Ordinária
# 1  21/09/2018   08:00:42         2018                2  Eleição Ordinária
# 2  21/09/2018   08:00:42         2018                2  Eleição Ordinária
#
#    CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO SG_UF SG_UE  \
# 0         297  Eleições Gerais Estaduais 2018  07/10/2018    RJ    RJ
# 1         297  Eleições Gerais Estaduais 2018  07/10/2018    RJ    RJ
# 2         297  Eleições Gerais Estaduais 2018  07/10/2018    MT    MT
#
#             NM_UE  SQ_CANDIDATO  NR_ORDEM_CANDIDATO  CD_TIPO_BEM_CANDIDATO  \
# 0  RIO DE JANEIRO  190000621107                  14                     61
# 1  RIO DE JANEIRO  190000621129                   1                     12
# 2     MATO GROSSO  110000612720                  23                     99
#
#                          DS_TIPO_BEM_CANDIDATO       DS_BEM_CANDIDATO  \
# 0  Depósito bancário em conta corrente no País                 #NULO#
# 1                                         Casa   casa em Mendes - RJ
# 2                       OUTROS BENS E DIREITOS  MUTUO PARA PORTO BELO
#
#    VR_BEM_CANDIDATO DT_ULTIMA_ATUALIZACAO HH_ULTIMA_ATUALIZACAO
# 0             87.07            19/09/2018              15:57:13
# 1          79000.00            19/09/2018              15:57:13
# 2         418800.00            11/09/2018              18:28:57

# %%
df_bens2 = df_bens[['SQ_CANDIDATO','CD_TIPO_BEM_CANDIDATO','DS_TIPO_BEM_CANDIDATO','DS_BEM_CANDIDATO','VR_BEM_CANDIDATO']]
df_bens2.head(3)
# Out:
#    SQ_CANDIDATO  CD_TIPO_BEM_CANDIDATO  \
# 0  190000621107                     61
# 1  190000621129                     12
# 2  110000612720                     99
#
#                          DS_TIPO_BEM_CANDIDATO       DS_BEM_CANDIDATO  \
# 0  Depósito bancário em conta corrente no País                 #NULO#
# 1                                         Casa   casa em Mendes - RJ
# 2                       OUTROS BENS E DIREITOS  MUTUO PARA PORTO BELO
#
#    VR_BEM_CANDIDATO
# 0             87.07
# 1          79000.00
# 2         418800.00

# %%
df_bens2.dtypes
# Out:
# SQ_CANDIDATO               int64
# CD_TIPO_BEM_CANDIDATO      int64
# DS_TIPO_BEM_CANDIDATO     object
# DS_BEM_CANDIDATO          object
# VR_BEM_CANDIDATO         float64
# dtype: object

# %%
df_bens_por_cand = df_bens2.groupby('SQ_CANDIDATO').apply(lambda x: x.to_dict(orient='records')).to_frame().reset_index()
df_bens_por_cand.columns = ['SQ_CANDIDATO','BENS']

# %%
print(df_bens_por_cand.dtypes)
df_bens_por_cand['BENS'][0]
# Out:
# SQ_CANDIDATO     int64
# BENS            object
# dtype: object
# [{'CD_TIPO_BEM_CANDIDATO': 12,
#   'DS_BEM_CANDIDATO': '#NULO#',
#   'DS_TIPO_BEM_CANDIDATO': 'Casa',
#   'SQ_CANDIDATO': 10000600001,
#   'VR_BEM_CANDIDATO': 180000.0},
#  {'CD_TIPO_BEM_CANDIDATO': 12,
#   'DS_BEM_CANDIDATO': '#NULO#',
#   'DS_TIPO_BEM_CANDIDATO': 'Casa',
#   'SQ_CANDIDATO': 10000600001,
#   'VR_BEM_CANDIDATO': 60000.0},
#  {'CD_TIPO_BEM_CANDIDATO': 21,
#   'DS_BEM_CANDIDATO': '#NULO#',
#   'DS_TIPO_BEM_CANDIDATO': 'Veículo automotor terrestre: caminhão, automóvel, moto, etc.',
#   'SQ_CANDIDATO': 10000600001,
#   'VR_BEM_CANDIDATO': 35830.96}]

# %%
df_bens_merged = pd.merge(left=df_cand, right=df_bens_por_cand, on='SQ_CANDIDATO', how='left')
df_bens_merged.head(5)
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  2018-09-21   08:00:57         2018                2  ELEIÇÃO ORDINÁRIA
# 1  2018-09-21   08:00:57         2018                2  ELEIÇÃO ORDINÁRIA
# 2  2018-09-21   08:00:57         2018                2  ELEIÇÃO ORDINÁRIA
# 3  2018-09-21   08:00:57         2018                2  ELEIÇÃO ORDINÁRIA
# 4  2018-09-21   08:00:57         2018                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  \
# 0         1         297  Eleições Gerais Estaduais 2018  2018-07-10
# 1         1         297  Eleições Gerais Estaduais 2018  2018-07-10
# 2         1         297  Eleições Gerais Estaduais 2018  2018-07-10
# 3         1         297  Eleições Gerais Estaduais 2018  2018-07-10
# 4         1         297  Eleições Gerais Estaduais 2018  2018-07-10
#
#   TP_ABRANGENCIA SG_UF SG_UE              NM_UE  CD_CARGO           DS_CARGO  \
# 0       ESTADUAL    TO    TO          TOCANTINS         7  DEPUTADO ESTADUAL
# 1       ESTADUAL    MG    MG       MINAS GERAIS         7  DEPUTADO ESTADUAL
# 2       ESTADUAL    RS    RS  RIO GRANDE DO SUL         7  DEPUTADO ESTADUAL
# 3       ESTADUAL    SC    SC     SANTA CATARINA         7  DEPUTADO ESTADUAL
# 4       ESTADUAL    PI    PI              PIAUÍ         5            SENADOR
#
#    SQ_CANDIDATO  NR_CANDIDATO                              NM_CANDIDATO  \
# 0  270000610942         45123                 GUTIERRES BORGES TORQUATO
# 1  130000605866         77500                REGINALDO MENEGUINI COSTA
# 2  210000604694         12220               LUIS ROGERIO MARENCO FERRAN
# 3  240000627318         43000  LAURO ALFREDO HORACIO SCHEUNEMANN SCHEEL
# 4  180000615099           444          FLÁVIA DA SILVA OLIVEIRA BARBOSA
#
#         NM_URNA_CANDIDATO NM_SOCIAL_CANDIDATO  NR_CPF_CANDIDATO  \
# 0      GUTIERRES TORQUATO              #NULO#         655089128
# 1  REGINALDO MENEGUINI DÚ              #NULO#       92869092687
# 2            LUIZ MARENCO              #NULO#       42430852004
# 3           LAURO SCHEEL               #NULO#        1045971863
# 4          FLÁVIA BARBOSA              #NULO#       62550128320
#
#                          NM_EMAIL  CD_SITUACAO_CANDIDATURA  \
# 0        GUTIERRES45123@GMAIL.COM                       12
# 1  REGINALDOMENEGUINI@HOTMAIL.COM                       12
# 2      CONTATO@LUIZMARENCO.COM.BR                       12
# 3         LAUROSCHEEL@HOTMAIL.COM                       12
# 4       FLAVIACOACH2016@GMAIL.COM                       12
#
#   DS_SITUACAO_CANDIDATURA  CD_DETALHE_SITUACAO_CAND DS_DETALHE_SITUACAO_CAND  \
# 0                    APTO                         2                 DEFERIDO
# 1                    APTO                         2                 DEFERIDO
# 2                    APTO                         2                 DEFERIDO
# 3                    APTO                         2                 DEFERIDO
# 4                    APTO                         2                 DEFERIDO
#
#      TP_AGREMIACAO  NR_PARTIDO     SG_PARTIDO  \
# 0        COLIGAÇÃO          45           PSDB
# 1  PARTIDO ISOLADO          77  SOLIDARIEDADE
# 2        COLIGAÇÃO          12            PDT
# 3        COLIGAÇÃO          43             PV
# 4  PARTIDO ISOLADO          44            PRP
#
#                                 NM_PARTIDO  SQ_COLIGACAO        NM_COLIGACAO  \
# 0  PARTIDO DA SOCIAL DEMOCRACIA BRASILEIRA  270000050293    RENOVA TOCANTINS
# 1                            SOLIDARIEDADE  130000050169     PARTIDO ISOLADO
# 2          PARTIDO DEMOCRÁTICO TRABALHISTA  210000050137  FRENTE TRABALHISTA
# 3                            PARTIDO VERDE  240000050745   AQUI TEM TRABALHO
# 4         PARTIDO REPUBLICANO PROGRESSISTA  180000050398     PARTIDO ISOLADO
#
#               DS_COMPOSICAO_COLIGACAO  CD_NACIONALIDADE DS_NACIONALIDADE  \
# 0  PSB / PSDB / PR / PODE / MDB / PSC                 1  BRASILEIRA NATA
# 1                       SOLIDARIEDADE                 1  BRASILEIRA NATA
# 2                           PDT / PMB                 1  BRASILEIRA NATA
# 3         DEM / PROS / PPL / PRP / PV                 1  BRASILEIRA NATA
# 4                                 PRP                 1  BRASILEIRA NATA
#
#   SG_UF_NASCIMENTO  CD_MUNICIPIO_NASCIMENTO NM_MUNICIPIO_NASCIMENTO  \
# 0               GO                       -3                  URUAÇU
# 1               MG                       -3           TRES CORAÇÕES
# 2               RS                       -3            PORTO ALEGRE
# 3               SC                       -3                BLUMENAU
# 4               PI                       -3                TERESINA
#
#   DT_NASCIMENTO  NR_IDADE_DATA_POSSE  NR_TITULO_ELEITORAL_CANDIDATO  \
# 0    1984-05-04                   34                    36280122771
# 1    1975-06-08                   43                    99429290221
# 2    1964-12-22                   54                    12726030469
# 3    1959-04-23                   59                   282150450159
# 4    1978-03-26                   40                    24746421589
#
#    CD_GENERO  DS_GENERO  CD_GRAU_INSTRUCAO      DS_GRAU_INSTRUCAO  \
# 0          2  MASCULINO                  8      SUPERIOR COMPLETO
# 1          2  MASCULINO                  8      SUPERIOR COMPLETO
# 2          2  MASCULINO                  6  ENSINO MÉDIO COMPLETO
# 3          2  MASCULINO                  8      SUPERIOR COMPLETO
# 4          4   FEMININO                  8      SUPERIOR COMPLETO
#
#    CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_COR_RACA DS_COR_RACA  CD_OCUPACAO  \
# 0                3       CASADO(A)            3       PARDA          114
# 1                3       CASADO(A)            3       PARDA          999
# 2                3       CASADO(A)            1      BRANCA          164
# 3                1     SOLTEIRO(A)            1      BRANCA          124
# 4                3       CASADO(A)            1      BRANCA          999
#
#                               DS_OCUPACAO  NR_DESPESA_MAX_CAMPANHA  \
# 0  FISIOTERAPEUTA E TERAPEUTA OCUPACIONAL                       -1
# 1                                  OUTROS                        0
# 2                                  MÚSICO                        0
# 3                                CONTADOR                        0
# 4                                  OUTROS                       -1
#
#    CD_SIT_TOT_TURNO DS_SIT_TOT_TURNO ST_REELEICAO ST_DECLARAR_BENS  \
# 0                -1           #NULO#            N                S
# 1                -1           #NULO#            N                S
# 2                -1           #NULO#            N                S
# 3                -1           #NULO#            N                S
# 4                -1           #NULO#            N                S
#
#    NR_PROTOCOLO_CANDIDATURA          NR_PROCESSO  \
# 0                        -1  6004977620186270000
# 1                        -1  6004993620186130000
# 2                        -1  6009642320186210000
# 3                        -1  6011497720186240000
# 4                        -1  6009546020186180000
#
#                                                 BENS
# 0  [{'SQ_CANDIDATO': 270000610942, 'CD_TIPO_BEM_C...
# 1  [{'SQ_CANDIDATO': 130000605866, 'CD_TIPO_BEM_C...
# 2  [{'SQ_CANDIDATO': 210000604694, 'CD_TIPO_BEM_C...
# 3  [{'SQ_CANDIDATO': 240000627318, 'CD_TIPO_BEM_C...
# 4  [{'SQ_CANDIDATO': 180000615099, 'CD_TIPO_BEM_C...

# %%
df_bens_merged.shape
# Out:
# (17615, 59)

# %%
df_bens_merged.to_json('datasets/export.json', orient='records', lines=True, date_format='iso')
